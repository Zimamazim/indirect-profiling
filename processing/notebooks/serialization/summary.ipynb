// %%
import profilelib.*

// %%
val data = mapOf(
    "original" to load_data("jfrs/serialization/replication/interval_and_iteration_study/"),
    "new_base_with_memory" to load_data("jfrs/serialization/replication/new_base_with_memory/"),
    "control" to load_data("jfrs/serialization/replication/control/"),
    "control2" to load_data("jfrs/serialization/replication/control2/"),
    "cstack-dwarf" to load_data("jfrs/serialization/cstack_dwarf/"),
)
// Out:
// '/home/martinzimen/IdeaProjects/stdlib-profiling/data/jfrs/serialization/replication/interval_and_iteration_study/platform=jvm,cycles=5000,sampleInterval=5,iteration=22.jfr'
// '/home/martinzimen/IdeaProjects/stdlib-profiling/data/jfrs/serialization/replication/interval_and_iteration_study/platform=native,cycles=100000,sampleInterval=5,iteration=9.jfr'
// '/home/martinzimen/IdeaProjects/stdlib-profiling/data/jfrs/serialization/replication/interval_and_iteration_study/platform=native,cycles=50000,sampleInterval=1,iteration=20.jfr'
// '/home/martinzimen/IdeaProjects/stdlib-profiling/data/jfrs/serialization/replication/interval_and_iteration_study/platform=jvm,cycles=100000,sampleInterval=1,iteration=19.jfr'
// '/home/martinzimen/IdeaProjects/stdlib-profiling/data/jfrs/serialization/replication/interval_and_iteration_study/platform=native,cycles=10000,sampleInterval=10,iteration=2.jfr'
// ...

// %%
data
    .mapValues { (name, dataset) -> dataset
        .filter { (params, _) -> params["sampleInterval"] == "100" && params["cycles"] == "100000" }
        .funRatio("java.lang.String.substring", "weirdo:Kotlin_String_subSequence")
        .map { it!! }
    }
    .toList()
    .partition { it.first == "cstack-dwarf" }
    .let { (cstackDwarf, other) ->
        compareVarianceAndBias(other.toMap())
        println()
        compareVarianceAndBias(cstackDwarf.toMap())
    }
// Out:
// original: 0.952 (0.061)
// new_base_with_memory: 0.956 (0.067)
// control: 0.951 (0.060)
// control2: 0.934 (0.067)
//
// Bias: 0.022482567839812617 (0.0237959379477148)
//
// cstack-dwarf: 0.162 (0.049)
//
// Bias: 0.0 (0.0)
