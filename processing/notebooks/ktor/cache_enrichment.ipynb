// %%
%use serialization
import profilelib.*
import java.io.FileOutputStream

val project_root = "/home/martinzimen/IdeaProjects/ktor-gdrive"

Json.encodeToStream(
    ktor_get_native_debug_map(project_root)
            to
    ktor_get_fun_to_src_map(project_root),
    FileOutputStream(dataPath("jfrs/ktor/enrichment.json"))
    )
// Out:
// Ambiguos DWARF info for 60 functions
