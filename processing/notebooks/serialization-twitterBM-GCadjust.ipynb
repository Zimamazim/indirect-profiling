warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=80.jfr'

// %%
data.funRatio("java.lang.String.substring", "weirdo:Kotlin_String_subSequence").let { println(formattedMeanCV(it.map { it!! })) }
dataNoGC.funRatio("java.lang.String.substring", "weirdo:Kotlin_String_subSequence").let { println(formattedMeanCV(it.map { it!! })) }
// Out:
// 0.162 (0.049)
// 0.174 (0.050)

// %% [markdown]
// This felt like a too small differece as in `StringSubstringBenchmark` the profiles show much larger time spent in GC. However, in the TwitterBM profiles, this roughly matches the saw values. Sweep really took 5--10% of `Kotlin_String_subSequence`.

// %%
data.funRatio("java.util.HashMap.get", "kotlin.collections.Map.get").let { println(formattedMeanCV(it.map { it!! })) }
dataNoGC.funRatio("java.util.HashMap.get", "kotlin.collections.Map.get").let { println(formattedMeanCV(it.map { it!! })) }
// Out:
// 0.129 (0.032)
// 0.129 (0.032)

// %%
data.funRatio("java.lang.StringBuilder.append", "kotlin.text.StringBuilder.append").also { println(formattedMeanCV(it.map { it!! })) }.let { println(mean(it.map { it!! })) }
dataNoGC.funRatio("java.lang.StringBuilder.append", "kotlin.text.StringBuilder.append").also { println(formattedMeanCV(it.map { it!! })) }.let { println(mean(it.map { it!! })) }
// Out:
// 0.037 (0.035)
// 0.037457188250623316
// 0.037 (0.035)
// 0.03749245169732162

// %% [markdown]
// TODO Investigate if the results are comparable. E.g., where does conversion from `Any` to `String` happen? In K/N it
// happens inside the call (i.e., the conversion counts as samples for this). How is it in JVM?
//
// In JVM, this is actually handled on `kx.serialization` part. It call `StringBuilder.append` only after `.toString()`
// call. Therefore, `kotlin.test.StringBuilder.append` needs to be broken down by signature and this summary value cannot
// be used.
//
// After further investigation, it actually seems that there is a custom performant and specialized StringBuilder impl
// at JVM. In K/N it's delegated to StringBuilder. Therefore, the implementation/wrapper needs to be filtered out.

// %%
import jdk.jfr.consumer.RecordedFrame

val dataStringBuilder = load_data("../../jfrStorage/serialization-twitterBM/cstack_dwarf/") {
    it
        .filterNot { it.any { it.method.name.contains("JsonToStringWriter") } }
        .filterNot { it.any { it.method.name.contains("kfun:kotlin.text.StringBuilder#append(kotlin.Long)") } && !it.any { it.method.name.contains("kfun:kotlin.text.StringBuilder#append(kotlin.String?)") } }
}
// Out:
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=43,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=10.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=44,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=50,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=20,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=48,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=67,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=8.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=33,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=26.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=25,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=63,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=29,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=45,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=81.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=76.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=73.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=14,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=83.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=70.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=6.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=80,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=97,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=27.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=40.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=34.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=40,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=83,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=23.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=4.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=32,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=92.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=79,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=72,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=13,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=91,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=74,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=44.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=61,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=57.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=99.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=77,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=47,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=65.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=55,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=64.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=50.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=43.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=28.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=98.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=58,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=20.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=39,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=94.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=47.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=23,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=92,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=51.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=88,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=93,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=24,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=51,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=60.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=42.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=12.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=53.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=22,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=91.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=69.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=97.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=96.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=62,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=74.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=7.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=41.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=58.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=76,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=57,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=75.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=16,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=17.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=46.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=84,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=9,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=9.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=3,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=68,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=1,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=1.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=73,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=96,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=26,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=10,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=18,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=82.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=37.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=46,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=19.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=59.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=25.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=36,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=72.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=2,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=71.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=66,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=17,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=15.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=59,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=95.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=53,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=60,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=34,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=12,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=87,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=49.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=85,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=21,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=61.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=77.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=31,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=28,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=27,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=38.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=54,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=2.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=5.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=21.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=63.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=19,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=56.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=11,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=93.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=75,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=89,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=48.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=15,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=94,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=62.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=88.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=65,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=100.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=29.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=52,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=69,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=31.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=100,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=11.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=37,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=56,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=6,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=18.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=78.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=68.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=99,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=52.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=13.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=82,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=32.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=89.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=30.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=90.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=86,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=87.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=81,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=41,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=4,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=35,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=39.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=78,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=55.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=67.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=16.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=14.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=86.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=24.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=38,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=90,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=79.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=36.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=7,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=98,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=30,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=22.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=95,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=70,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=84.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=64,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=45.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=49,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=33.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=71,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=8,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=66.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=42,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=85.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=35.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=54.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=jvm,cycles=100000,sampleInterval=100,iteration=5,warmup=3.jfr'
// '../../jfrStorage/serialization-twitterBM/cstack_dwarf/platform=native,cycles=100000,sampleInterval=100,iteration=80.jfr'

// %%
dataStringBuilder.funRatio("java.lang.StringBuilder.append", "kotlin.text.StringBuilder.append").let { println(formattedMeanCV(it.map { it!! })) }
// Out:
// 0.154 (0.036)
