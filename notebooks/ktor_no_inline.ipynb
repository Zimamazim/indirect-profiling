// %%
import jfr_processor.profilelib.*

val project_root = "/home/Martin.Zimen/IdeaProjects/ktor/"
val profile_root = project_root + "profiler_output_weekend/"

// %%
val native_debug_map = ktor_get_native_debug_map(project_root)
val jvm_fun_to_src_map = ktor_get_fun_to_src_map(project_root)
// Out:
// Ambiguos DWARF info for 60 functions

// %%
val jvm_freq = mutableMapOf<String, Int>()
val native_freq = mutableMapOf<String, Int>()

get_valid_tests(profile_root).forEach { testname ->
    lazy_samples(profile_root + "jvm-" + testname + ".jfr")
        .mapNotNull { truncate_stack_trace(it) { jvm_get_name(it) == testname } }
        .filter { jvm_is_sample_platform_independent(it, jvm_fun_to_src_map) }
        .toFreq(jvm_freq, ::jvm_get_name)

    lazy_samples(profile_root + "linuxX64-" + testname + ".jfr")
        .mapNotNull { truncate_stack_trace(it) { native_get_name(it)?.contains(testname) ?: false } }
        .filter { native_is_sample_platform_independent(it, native_debug_map) }
        .toFreq(native_freq, ::native_get_name)
}
// Out:
// ERROR: jvm-io.ktor.client.plugins.compression.ContentEncodingTest.testNoEncoding
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testBasicAuthPerRealm
// ERROR: jvm-io.ktor.test.RunTestWithDataTest.testSuccessAfterTimeoutItem
// ERROR: jvm-io.ktor.server.config.yaml.YamlConfigTest.testEnvironmentVariable
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testBasicAuthMultiple
// ERROR: jvm-io.ktor.client.tests.plugins.WebSocketRemoteTest.testErrorHandling
// ERROR: jvm-io.ktor.client.plugins.bomremover.BomRemoverTest.testNoBody
// ERROR: jvm-io.ktor.client.tests.plugins.WebSocketRemoteTest.testSessionTermination
// ERROR: jvm-io.ktor.server.config.yaml.YamlConfigTest.testExistingEnvironmentVariableWithDefault
// ERROR: jvm-io.ktor.client.plugins.compression.ContentEncodingTest.testDeflate
// ERROR: jvm-io.ktor.client.tests.plugins.WebSocketRemoteTest.testSessionClose
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testDigestAuthSHA256
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testUnauthorizedDoesNotRefreshTokenWithoutWWWAuthenticateHeaderIfMultipleProvidersAreInstalled
// ERROR: linuxX64-WriterReaderTest.testWriterOnCancelled
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testUnauthorizedBearerAuthWithValidAccessTokenAndInvalidRefreshToken
// ERROR: jvm-io.ktor.test.RunTestWithDataTest.testFailByTimeout
// ERROR: jvm-io.ktor.client.tests.plugins.WebSocketRemoteTest.testRemotePingPong
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testDigestAuth
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testForbiddenBearerAuthWithInvalidAccessAndValidRefreshTokens
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testMultipleChallengesInHeaderUnauthorized
// ERROR: jvm-io.ktor.test.RunTestWithDataTest.testDifferentItemsHaveIndependentTimeout
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testUnauthorizedBasicAuth
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testBasicAuthWithoutNegotiationLegacy
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testRefreshOnBackgroundThread
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testRefreshWithSameClient
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testBasicAuthWithoutNegotiation
// ERROR: linuxX64-io.ktor.tests.http.cio.HttpHeadersMapTest.testHeadersMapResize
// ERROR: jvm-io.ktor.server.config.yaml.YamlConfigTest.testOptionalExistingEnvironmentVariable
// ERROR: jvm-io.ktor.client.plugins.compression.ContentEncodingTest.testGzipByteArray
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testBasicAuthMultipleNotSendWithoutRequest
// ERROR: jvm-io.ktor.test.RunTestWithDataTest.testRetriesHaveIndependentTimeout
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testDigestAuthPerRealm
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testBasicAuth
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testRefreshWithSameClientInBlock
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testRefreshReplies401
// ERROR: jvm-io.ktor.client.plugins.compression.ContentEncodingTest.testIdentity
// ERROR: jvm-io.ktor.client.tests.plugins.WebSocketRemoteTest.testBadCloseReason
// ERROR: jvm-io.ktor.test.RunTestWithDataTest.testRetryAfterTimeout
// ERROR: jvm-io.ktor.test.RunTestWithDataTest.testExecutionOrderPreserved
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testLoadTokenAfterClear
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testBasicAuthLegacy
// ERROR: jvm-CoroutinesTest.testWriterWithExtraFlush
// ERROR: jvm-io.ktor.client.tests.plugins.WebSocketRemoteTest.testWithLogging
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testUnauthorizedRefreshTokenWithoutWWWAuthenticateHeaderIfOneProviderIsInstalled
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testMultipleChallengesInMultipleHeadersUnauthorized
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testUnauthorizedBearerAuthWithInvalidAccessAndRefreshTokens
// ERROR: jvm-io.ktor.client.tests.plugins.WebSocketRemoteTest.testNotFound
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testMultipleChallengesInHeaders
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testDigestAuthLegacy
// ERROR: linuxX64-io.ktor.util.ChannelTest.testCopyToBothCancelFirstReader
// ERROR: jvm-io.ktor.client.plugins.bomremover.BomRemoverTest.testRemoveBomCorrectly
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testUnauthorizedBearerAuthWithInvalidAccessAndRefreshTokensAsNulls
// ERROR: jvm-io.ktor.client.plugins.compression.ContentEncodingTest.testGZip
// ERROR: jvm-io.ktor.client.plugins.compression.ContentEncodingTest.testDisableDecompression
// ERROR: jvm-io.ktor.client.plugins.auth.AuthTest.testUnauthorizedBasicAuthLegacy
// ERROR: jvm-io.ktor.client.plugins.bomremover.BomRemoverTest.testNoBom
// ERROR: jvm-WriterReaderTest.testReaderOnCancelled
// ERROR: jvm-io.ktor.client.plugins.compression.ContentEncodingTest.testGZipEmpty
// ERROR: linuxX64-io.ktor.util.ChannelTest.testCopyToBothCancelSecondReader

// %%
match_and_compare_freqs(jvm_freq, native_freq) { it.second.jvm_count > 2 && it.second.native_count > 2 }
// Out:
// toByteArray
// 2.2
// JVM: 5
// (kotlin.collections.CollectionsKt___CollectionsKt.toByteArray, 5)
//
// Native: 11
// (kotlin.collections.toByteArray__at__kotlin.collections.Collection<kotlin.Byte>, 11)
//
//
// first
// 1.8888888
// JVM: 90
// (kotlin.text.StringsKt___StringsKt.first, 25)
// (kotlin.collections.CollectionsKt___CollectionsKt.first, 65)
//
// Native: 170
// (kotlin.text.first__at__kotlin.CharSequence, 88)
// (kotlin.collections.first__at__kotlin.collections.List<0:0>, 79)
// (kotlin.collections.first__at__kotlin.collections.Iterable<0:0>, 3)
//
//
// component1
// 1.882353
// JVM: 17
// (kotlin.Pair.component1, 17)
//
// Native: 32
// (kotlin.Pair.component1, 32)
//
//
// component2
// 1.625
// JVM: 8
// (kotlin.Pair.component2, 8)
//
// Native: 13
// (kotlin.Pair.component2, 13)
//
//
// assertNotSame
// 1.3333334
// JVM: 12
// (kotlin.test.junit5.JUnit5Asserter.assertNotSame, 2)
// (kotlin.test.AssertionsKt__AssertionsKt.assertNotSame, 5)
// (kotlin.test.AssertionsKt.assertNotSame, 5)
//
// Native: 16
// (kotlin.test.Asserter.assertNotSame, 9)
// (kotlin.test.assertNotSame, 7)
//
//
// drop
// 1.2777778
// JVM: 18
// (kotlin.collections.CollectionsKt___CollectionsKt.drop, 18)
//
// Native: 23
// (kotlin.collections.drop__at__kotlin.collections.Iterable<0:0>, 23)
//
//
// lazy
// 1.1615461
// JVM: 1009
// (kotlin.LazyKt__LazyJVMKt.lazy, 1009)
//
// Native: 1172
// (kotlin.lazy, 1172)
//
//
// assertTrue
// 0.96002287
// JVM: 3502
// (kotlin.test.junit5.JUnit5Asserter.assertTrue, 664)
// (kotlin.test.Asserter$DefaultImpls.assertTrue, 543)
// (kotlin.test.AssertionsKt__AssertionsKt.assertTrue, 1120)
// (kotlin.test.AssertionsKt.assertTrue, 1175)
//
// Native: 3362
// (kotlin.test.Asserter.assertTrue, 3130)
// (kotlin.test.assertTrue, 232)
//
//
// coerceAtMost
// 0.85714287
// JVM: 7
// (kotlin.ranges.RangesKt___RangesKt.coerceAtMost, 7)
//
// Native: 6
// (kotlin.ranges.coerceAtMost__at__kotlin.Int, 4)
// (kotlin.ranges.coerceAtMost__at__kotlin.Long, 2)
//
//
// dropLast
// 0.8125
// JVM: 96
// (kotlin.text.StringsKt___StringsKt.dropLast, 22)
// (kotlin.collections.CollectionsKt___CollectionsKt.dropLast, 74)
//
// Native: 78
// (kotlin.text.dropLast__at__kotlin.String, 19)
// (kotlin.collections.dropLast__at__kotlin.collections.List<0:0>, 59)
//
//
// assertNull
// 0.75536484
// JVM: 466
// (kotlin.test.AssertionsKt__AssertionsKt.assertNull, 227)
// (kotlin.test.AssertionsKt.assertNull, 228)
// (kotlin.test.junit5.JUnit5Asserter.assertNull, 11)
//
// Native: 352
// (kotlin.test.Asserter.assertNull, 176)
// (kotlin.test.assertNull, 176)
//
//
// collectionSizeOrDefault
// 0.6988764
// JVM: 445
// (kotlin.collections.CollectionsKt__IterablesKt.collectionSizeOrDefault, 445)
//
// Native: 311
// (kotlin.collections.collectionSizeOrDefault__at__kotlin.collections.Iterable<0:0>, 311)
//
//
// assertIterableContentEquals
// 0.6111111
// JVM: 18
// (kotlin.test.AssertContentEqualsImplKt.assertIterableContentEquals, 18)
//
// Native: 11
// (kotlin.test.assertIterableContentEquals, 11)
//
//
// mapOf
// 0.6
// JVM: 105
// (kotlin.collections.MapsKt__MapsKt.mapOf, 91)
// (kotlin.collections.MapsKt__MapsJVMKt.mapOf, 14)
//
// Native: 63
// (kotlin.collections.mapOf, 63)
//
//
// assertNotSame$default
// 0.5714286
// JVM: 14
// (kotlin.test.AssertionsKt__AssertionsKt.assertNotSame$default, 6)
// (kotlin.test.AssertionsKt.assertNotSame$default, 8)
//
// Native: 8
// (kotlin.test.assertNotSame$default, 8)
//
//
// joinTo$default
// 0.5413929
// JVM: 761
// (kotlin.collections.CollectionsKt___CollectionsKt.joinTo$default, 761)
//
// Native: 412
// (kotlin.collections.joinTo$default__at__kotlin.collections.Iterable<0:0>, 412)
//
//
// joinToString$default
// 0.53860295
// JVM: 2176
// (kotlin.collections.CollectionsKt___CollectionsKt.joinToString$default, 2110)
// (kotlin.collections.ArraysKt___ArraysKt.joinToString$default, 66)
//
// Native: 1172
// (kotlin.collections.joinToString$default__at__kotlin.collections.Iterable<0:0>, 1166)
// (kotlin.collections.joinToString$default__at__kotlin.Array<out|0:0>, 6)
//
//
// take
// 0.52307695
// JVM: 65
// (kotlin.text.StringsKt___StringsKt.take, 14)
// (kotlin.collections.CollectionsKt___CollectionsKt.take, 48)
// (kotlin.sequences.SequencesKt___SequencesKt.take, 3)
//
// Native: 34
// (kotlin.text.take__at__kotlin.String, 7)
// (kotlin.collections.take__at__kotlin.collections.Iterable<0:0>, 27)
//
//
// until
// 0.5205479
// JVM: 73
// (kotlin.ranges.RangesKt___RangesKt.until, 73)
//
// Native: 38
// (kotlin.ranges.until__at__kotlin.Int, 32)
// (kotlin.ranges.until__at__kotlin.Long, 6)
//
//
// joinToString
// 0.4622093
// JVM: 2064
// (kotlin.collections.CollectionsKt___CollectionsKt.joinToString, 1999)
// (kotlin.collections.ArraysKt___ArraysKt.joinToString, 65)
//
// Native: 954
// (kotlin.collections.joinToString__at__kotlin.collections.Iterable<0:0>, 949)
// (kotlin.collections.joinToString__at__kotlin.Array<out|0:0>, 5)
//
//
// assertEquals
// 0.40009394
// JVM: 29803
// (kotlin.test.AssertionsKt__AssertionsKt.assertEquals, 11610)
// (kotlin.test.AssertionsKt.assertEquals, 11665)
// (kotlin.test.junit5.JUnit5Asserter.assertEquals, 6528)
//
// Native: 11924
// (kotlin.test.Asserter.assertEquals, 6887)
// (kotlin.test.assertEquals, 5037)
//
//
// joinTo
// 0.39451116
// JVM: 2332
// (kotlin.collections.CollectionsKt___CollectionsKt.joinTo, 2275)
// (kotlin.collections.ArraysKt___ArraysKt.joinTo, 57)
//
// Native: 920
// (kotlin.collections.joinTo__at__kotlin.collections.Iterable<0:0>, 917)
// (kotlin.collections.joinTo__at__kotlin.Array<out|0:0>, 3)
//
//
// assertSame
// 0.3809524
// JVM: 105
// (kotlin.test.AssertionsKt__AssertionsKt.assertSame, 49)
// (kotlin.test.AssertionsKt.assertSame, 49)
// (kotlin.test.junit5.JUnit5Asserter.assertSame, 7)
//
// Native: 40
// (kotlin.test.assertSame, 21)
// (kotlin.test.Asserter.assertSame, 19)
//
//
// assertNull$default
// 0.3716475
// JVM: 522
// (kotlin.test.AssertionsKt.assertNull$default, 282)
// (kotlin.test.AssertionsKt__AssertionsKt.assertNull$default, 240)
//
// Native: 194
// (kotlin.test.assertNull$default, 194)
//
//
// last
// 0.36426118
// JVM: 291
// (kotlin.collections.CollectionsKt___CollectionsKt.last, 90)
// (kotlin.text.StringsKt___StringsKt.last, 10)
// (kotlin.sequences.SequencesKt___SequencesKt.last, 191)
//
// Native: 106
// (kotlin.collections.last__at__kotlin.collections.List<0:0>, 92)
// (kotlin.text.last__at__kotlin.CharSequence, 9)
// (kotlin.collections.last__at__kotlin.collections.Iterable<0:0>, 5)
//
//
// emptyList
// 0.36099586
// JVM: 241
// (kotlin.collections.CollectionsKt__CollectionsKt.emptyList, 241)
//
// Native: 87
// (kotlin.collections.emptyList, 87)
//
//
// putAll
// 0.34065935
// JVM: 91
// (kotlin.collections.MapsKt__MapsKt.putAll, 91)
//
// Native: 31
// (kotlin.collections.putAll__at__kotlin.collections.MutableMap<in|0:0,in|0:1>, 31)
//
//
// toMap
// 0.33497536
// JVM: 203
// (kotlin.collections.MapsKt__MapsKt.toMap, 203)
//
// Native: 68
// (kotlin.collections.toMap__at__kotlin.Array<out|kotlin.Pair<0:0,0:1>>, 32)
// (kotlin.collections.toMap__at__kotlin.collections.Iterable<kotlin.Pair<0:0,0:1>>, 35)
// (kotlin.collections.toMap__at__kotlin.collections.Map<out|0:0,0:1>, 1)
//
//
// assertNotEquals
// 0.28448275
// JVM: 116
// (kotlin.test.AssertionsKt__AssertionsKt.assertNotEquals, 44)
// (kotlin.test.AssertionsKt.assertNotEquals, 44)
// (kotlin.test.junit5.JUnit5Asserter.assertNotEquals, 28)
//
// Native: 33
// (kotlin.test.Asserter.assertNotEquals, 16)
// (kotlin.test.assertNotEquals, 17)
//
//
// filterNotNull
// 0.25
// JVM: 44
// (kotlin.collections.ArraysKt___ArraysKt.filterNotNull, 44)
//
// Native: 11
// (kotlin.collections.filterNotNull__at__kotlin.Array<out|0:0?>, 11)
//
//
// to
// 0.24421594
// JVM: 389
// (kotlin.TuplesKt.to, 389)
//
// Native: 95
// (kotlin.to__at__0:0, 95)
//
//
// fail
// 0.2404674
// JVM: 4878
// (kotlin.test.AssertionsKt.fail, 1646)
// (kotlin.test.AssertionsKt__AssertionsKt.fail, 1634)
// (kotlin.test.junit5.JUnit5Asserter.fail, 1598)
//
// Native: 1173
// (kotlin.test.Asserter.fail, 1146)
// (kotlin.test.DefaultAsserter.fail, 27)
//
//
// get
// 0.23552467
// JVM: 16839
// (kotlin.coroutines.CoroutineContext$Element$DefaultImpls.get, 1745)
// (kotlin.coroutines.AbstractCoroutineContextElement.get, 2051)
// (kotlin.coroutines.CombinedContext.get, 11739)
// (kotlin.coroutines.ContinuationInterceptor$DefaultImpls.get, 1090)
// (kotlin.coroutines.EmptyCoroutineContext.get, 204)
// (kotlin.enums.EnumEntriesList.get, 10)
//
// Native: 3966
// (kotlin.coroutines.ContinuationInterceptor.get, 80)
// (kotlin.coroutines.CoroutineContext.Element.get, 731)
// (kotlin.coroutines.CombinedContext.get, 1106)
// (kotlin.coroutines.CoroutineContext.get, 1989)
// (kotlin.coroutines.EmptyCoroutineContext.get, 60)
//
//
// filterNotNullTo
// 0.22580644
// JVM: 31
// (kotlin.collections.ArraysKt___ArraysKt.filterNotNullTo, 31)
//
// Native: 7
// (kotlin.collections.filterNotNullTo__at__kotlin.Array<out|0:1?>, 7)
//
//
// flatten
// 0.21875
// JVM: 32
// (kotlin.collections.CollectionsKt__IterablesKt.flatten, 32)
//
// Native: 7
// (kotlin.collections.flatten__at__kotlin.collections.Iterable<kotlin.collections.Iterable<0:0>>, 7)
//
//
// assertContentEquals
// 0.21794872
// JVM: 78
// (kotlin.test.AssertionsKt__AssertionsKt.assertContentEquals, 39)
// (kotlin.test.AssertionsKt.assertContentEquals, 39)
//
// Native: 17
// (kotlin.test.assertContentEquals, 17)
//
//
// assertSame$default
// 0.21551724
// JVM: 116
// (kotlin.test.AssertionsKt.assertSame$default, 65)
// (kotlin.test.AssertionsKt__AssertionsKt.assertSame$default, 51)
//
// Native: 25
// (kotlin.test.assertSame$default, 25)
//
//
// assertEquals$default
// 0.21549588
// JVM: 25026
// (kotlin.test.AssertionsKt__AssertionsKt.assertEquals$default, 11726)
// (kotlin.test.AssertionsKt.assertEquals$default, 13300)
//
// Native: 5393
// (kotlin.test.assertEquals$default, 5393)
//
//
// appendElement
// 0.20454545
// JVM: 1100
// (kotlin.text.StringsKt__AppendableKt.appendElement, 1100)
//
// Native: 225
// (kotlin.text.appendElement__at__kotlin.text.Appendable, 225)
//
//
// checkResultIsFailure
// 0.2032641
// JVM: 674
// (kotlin.test.AssertionsKt.checkResultIsFailure, 397)
// (kotlin.test.AssertionsKt__AssertionsImplKt.checkResultIsFailure, 272)
// (kotlin.test.AssertionsKt__AssertionsKt.checkResultIsFailure, 5)
//
// Native: 137
// (kotlin.test.checkResultIsFailure, 137)
//
//
// assertContentEquals$default
// 0.20183486
// JVM: 109
// (kotlin.test.AssertionsKt.assertContentEquals$default, 68)
// (kotlin.test.AssertionsKt__AssertionsKt.assertContentEquals$default, 41)
//
// Native: 22
// (kotlin.test.assertContentEquals$default, 22)
//
//
// assertNotNull
// 0.2006079
// JVM: 329
// (kotlin.test.AssertionsKt__AssertionsKt.assertNotNull, 160)
// (kotlin.test.AssertionsKt.assertNotNull, 162)
// (kotlin.test.junit5.JUnit5Asserter.assertNotNull, 7)
//
// Native: 66
// (kotlin.test.Asserter.assertNotNull, 27)
// (kotlin.test.assertNotNull, 39)
//
//
// assertNotEquals$default
// 0.185567
// JVM: 97
// (kotlin.test.AssertionsKt.assertNotEquals$default, 51)
// (kotlin.test.AssertionsKt__AssertionsKt.assertNotEquals$default, 46)
//
// Native: 18
// (kotlin.test.assertNotEquals$default, 18)
//
//
// asList
// 0.14673913
// JVM: 552
// (kotlin.collections.ArraysUtilJVM.asList, 161)
// (kotlin.collections.ArraysKt___ArraysJvmKt.asList, 391)
//
// Native: 81
// (kotlin.collections.asList__at__kotlin.Array<out|0:0>, 81)
//
//
// addAll
// 0.14652015
// JVM: 819
// (kotlin.collections.CollectionsKt__MutableCollectionsKt.addAll, 819)
//
// Native: 120
// (kotlin.collections.addAll__at__kotlin.collections.MutableCollection<in|0:0>, 120)
//
//
// coerceAtLeast
// 0.14285715
// JVM: 21
// (kotlin.ranges.RangesKt___RangesKt.coerceAtLeast, 21)
//
// Native: 3
// (kotlin.ranges.coerceAtLeast__at__kotlin.Int, 3)
//
//
// emptySet
// 0.11827957
// JVM: 93
// (kotlin.collections.SetsKt__SetsKt.emptySet, 93)
//
// Native: 11
// (kotlin.collections.emptySet, 11)
//
//
// assertNotNull$default
// 0.112021856
// JVM: 366
// (kotlin.test.AssertionsKt.assertNotNull$default, 200)
// (kotlin.test.AssertionsKt__AssertionsKt.assertNotNull$default, 166)
//
// Native: 41
// (kotlin.test.assertNotNull$default, 41)
//
//
// firstOrNull
// 0.09966777
// JVM: 301
// (kotlin.collections.CollectionsKt___CollectionsKt.firstOrNull, 301)
//
// Native: 30
// (kotlin.collections.firstOrNull__at__kotlin.collections.List<0:0>, 30)
//
//
// <init>
// 0.09840099
// JVM: 5691
// (kotlin.ranges.CharProgression.<init>, 55)
// (kotlin.ranges.CharRange.<init>, 57)
// (kotlin.test.junit5.JUnit5Contributor.<init>, 1714)
// (kotlin.Pair.<init>, 104)
// (kotlin.ranges.CharProgressionIterator.<init>, 7)
// (kotlin.time.AbstractLongTimeSource.<init>, 1200)
// (kotlin.coroutines.CombinedContext.<init>, 742)
// (kotlin.Result$Failure.<init>, 190)
// (kotlin.coroutines.AbstractCoroutineContextElement.<init>, 267)
// (kotlin.SynchronizedLazyImpl.<init>, 859)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007e46481694c0.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007c25541865c0.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007c25541a5800.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x000079a8001a7af0.<init>, 1)
// (kotlin.ranges.IntProgression.<init>, 67)
// (kotlin.ranges.IntRange.<init>, 79)
// (kotlin.sequences.SequencesKt__SequenceBuilderKt$sequence$$inlined$Sequence$1.<init>, 12)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007a9054151df8.<init>, 1)
// (kotlin.collections.ArrayAsCollection.<init>, 27)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x0000705af816da10.<init>, 2)
// (kotlin.collections.builders.ListBuilder$Itr.<init>, 4)
// (kotlin.ranges.CharProgression$Companion.<init>, 2)
// (kotlin.reflect.KTypeProjection.<init>, 4)
// (kotlin.sequences.SequencesKt__SequencesKt$asSequence$$inlined$Sequence$1.<init>, 2)
// (kotlin.sequences.SequenceBuilderIterator.<init>, 8)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007f61c8164c30.<init>, 1)
// (kotlin.sequences.ConstrainedOnceSequence.<init>, 5)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x0000713dc4160450.<init>, 1)
// (kotlin.test.junit5.JUnit5Asserter.<init>, 1)
// (kotlin.sequences.SequenceScope.<init>, 4)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007f6f001694c0.<init>, 1)
// (kotlin.coroutines.AbstractCoroutineContextKey.<init>, 3)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007f51401694c0.<init>, 1)
// (kotlin.time.Duration.<init>, 1)
// (kotlin.time.TimeSource$Monotonic$ValueTimeMark.<init>, 11)
// (kotlin.ranges.LongRange.<init>, 23)
// (kotlin.ranges.LongProgression.<init>, 18)
// (kotlin.enums.EnumEntriesList.<init>, 2)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x000075608c1694c0.<init>, 4)
// (kotlin.text.Regex.<init>, 4)
// (kotlin.UnsafeLazyImpl.<init>, 19)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007cf16c1fbb60.<init>, 1)
// (kotlin.ranges.IntProgressionIterator.<init>, 2)
// (kotlin.coroutines.EmptyCoroutineContext.<init>, 2)
// (kotlin.coroutines.intrinsics.CoroutineSingletons.<init>, 3)
// (kotlin.time.DurationUnit.<init>, 1)
// (kotlin.Result$Companion.<init>, 2)
// (kotlin.sequences.TransformingSequence$iterator$1.<init>, 62)
// (kotlin.text.DelimitedRangesSequence$iterator$1.<init>, 9)
// (kotlin.text.DelimitedRangesSequence.<init>, 2)
// (kotlin.ranges.IntRange$Companion.<init>, 4)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007867e41a9028.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x000078a370164c30.<init>, 1)
// (kotlin.LazyThreadSafetyMode.<init>, 1)
// (kotlin.sequences.TransformingSequence.<init>, 8)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007888d815e2d8.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x0000747af0164838.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007935b41865c0.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007f72d8156a70.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x0000740f681666b0.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x0000763ad8152ca0.<init>, 2)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007c8a381694c0.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007952941863c8.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007fe0a81865c0.<init>, 1)
// (kotlin.collections.AbstractCollection.<init>, 1)
// (kotlin.collections.AbstractList.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x0000725a8c1a7710.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x000074ba881a4848.<init>, 1)
// (kotlin.test.AssertionsKt__AssertionsKt$$Lambda.0x00007970e821e000.<init>, 1)
// (kotlin.SafePublicationLazyImpl.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x0000720b5c15a418.<init>, 1)
// (kotlin.sequences.TakeSequence$iterator$1.<init>, 32)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007c1940165fe8.<init>, 2)
// (kotlin.coroutines.ContinuationInterceptor$Key.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x0000741fa0162260.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007400dc21a050.<init>, 2)
// (kotlin.text.LinesIterator$State.<init>, 2)
// (kotlin.text.StringsKt__StringsKt$lineSequence$$inlined$Sequence$1.<init>, 3)
// (kotlin.text.LinesIterator.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007363341694c0.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x0000707934168cc0.<init>, 1)
// (kotlin.collections.EmptyIterator.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007784c4154b80.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x000078b9641666b0.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007536f415f2a8.<init>, 1)
// (kotlin.coroutines.CoroutineContext$DefaultImpls$$Lambda.0x000074bdc41698d0.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x000073c4641863c8.<init>, 3)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x0000775ce4164c30.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x0000763bf01694c0.<init>, 1)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x00007fd974156378.<init>, 3)
// (kotlin.test.Asserter$DefaultImpls$$Lambda.0x0000706948156cb8.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007dd360164c30.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007bba38168cc0.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x000077a3101865c0.<init>, 1)
// (kotlin.Unit.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x000072c1181865c0.<init>, 1)
// (kotlin.text.StringsKt__StringsKt$$Lambda.0x000073ddd415cac0.<init>, 1)
// (kotlin.text.StringsKt__StringsKt$$Lambda.0x00007911a4156d78.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007b1a601863c8.<init>, 1)
// (kotlin.time.AbstractLongTimeSource$$Lambda.0x00007652d816da10.<init>, 1)
//
// Native: 560
// (kotlin.test.Asserter.Asserter$assertEquals$1.<init>, 500)
// (kotlin.test.Asserter.Asserter$assertTrue$1.<init>, 25)
// (kotlin.test.Asserter.Asserter$assertNull$1.<init>, 28)
// (kotlin.test.Asserter.Asserter$assertNotNull$1.<init>, 3)
// (kotlin.test.Asserter.Asserter$assertNotEquals$1.<init>, 2)
// (kotlin.test.Asserter.Asserter$assertSame$1.<init>, 2)
//
//
// sortedWith
// 0.09501558
// JVM: 642
// (kotlin.collections.CollectionsKt___CollectionsKt.sortedWith, 642)
//
// Native: 61
// (kotlin.collections.sortedWith__at__kotlin.collections.Iterable<0:0>, 61)
//
//
// assertFalse
// 0.080449015
// JVM: 1069
// (kotlin.test.AssertionsKt__AssertionsKt.assertFalse, 529)
// (kotlin.test.AssertionsKt.assertFalse, 540)
//
// Native: 86
// (kotlin.test.assertFalse, 86)
//
//
// sortWith
// 0.08029197
// JVM: 274
// (kotlin.collections.ArraysKt___ArraysJvmKt.sortWith, 274)
//
// Native: 22
// (kotlin.collections.sortWith__at__kotlin.Array<out|0:0>, 22)
//
//
// assertTrue$default
// 0.077783994
// JVM: 1787
// (kotlin.test.AssertionsKt__AssertionsKt.assertTrue$default, 780)
// (kotlin.test.AssertionsKt.assertTrue$default, 1007)
//
// Native: 139
// (kotlin.test.assertTrue$default, 139)
//
//
// mutableListOf
// 0.07440476
// JVM: 336
// (kotlin.collections.CollectionsKt__CollectionsKt.mutableListOf, 336)
//
// Native: 25
// (kotlin.collections.mutableListOf, 25)
//
//
// listOf
// 0.06762576
// JVM: 10218
// (kotlin.collections.CollectionsKt__CollectionsKt.listOf, 10003)
// (kotlin.collections.CollectionsKt__CollectionsJVMKt.listOf, 215)
//
// Native: 691
// (kotlin.collections.listOf, 691)
//
//
// assertFalse$default
// 0.052540913
// JVM: 1161
// (kotlin.test.AssertionsKt.assertFalse$default, 661)
// (kotlin.test.AssertionsKt__AssertionsKt.assertFalse$default, 500)
//
// Native: 61
// (kotlin.test.assertFalse$default, 61)
//
//
// createCoroutineUnintercepted
// 0.026785715
// JVM: 1568
// (kotlin.coroutines.intrinsics.IntrinsicsKt__IntrinsicsJvmKt.createCoroutineUnintercepted, 1568)
//
// Native: 42
// (kotlin.coroutines.intrinsics.createCoroutineUnintercepted__at__kotlin.coroutines.SuspendFunction0<0:0>, 42)
//
//
// toList
// 0.024038462
// JVM: 3952
// (kotlin.collections.CollectionsKt___CollectionsKt.toList, 3069)
// (kotlin.collections.ArraysKt___ArraysKt.toList, 54)
// (kotlin.sequences.SequencesKt___SequencesKt.toList, 825)
// (kotlin.collections.MapsKt___MapsKt.toList, 4)
//
// Native: 95
// (kotlin.collections.toList__at__kotlin.ByteArray, 49)
// (kotlin.collections.toList__at__kotlin.Array<out|0:0>, 41)
// (kotlin.sequences.toList__at__kotlin.sequences.Sequence<0:0>, 2)
// (kotlin.collections.toList__at__kotlin.collections.Iterable<0:0>, 3)
//
//
// plus
// 0.01798156
// JVM: 28418
// (kotlin.collections.CollectionsKt___CollectionsKt.plus, 1364)
// (kotlin.coroutines.CoroutineContext$Element$DefaultImpls.plus, 3231)
// (kotlin.coroutines.CoroutineContext$DefaultImpls.plus, 12552)
// (kotlin.coroutines.CombinedContext.plus, 9815)
// (kotlin.coroutines.AbstractCoroutineContextElement.plus, 1306)
// (kotlin.coroutines.EmptyCoroutineContext.plus, 136)
// (kotlin.collections.SetsKt___SetsKt.plus, 14)
//
// Native: 511
// (kotlin.collections.plus__at__kotlin.collections.Collection<0:0>, 474)
// (kotlin.collections.plus__at__kotlin.collections.Iterable<0:0>, 37)
//
//
// copyInto
// 0.017727273
// JVM: 2200
// (kotlin.collections.ArraysKt___ArraysJvmKt.copyInto, 2200)
//
// Native: 39
// (kotlin.collections.copyInto__at__kotlin.Array<out|0:0>, 39)
//
//
// toMutableList
// 0.016567677
// JVM: 3199
// (kotlin.collections.CollectionsKt___CollectionsKt.toMutableList, 3172)
// (kotlin.collections.ArraysKt___ArraysKt.toMutableList, 27)
//
// Native: 53
// (kotlin.collections.toMutableList__at__kotlin.ByteArray, 42)
// (kotlin.collections.toMutableList__at__kotlin.collections.Collection<0:0>, 9)
// (kotlin.collections.toMutableList__at__kotlin.Array<out|0:0>, 2)
//
//
// toSet
// 0.014667817
// JVM: 1159
// (kotlin.collections.CollectionsKt___CollectionsKt.toSet, 908)
// (kotlin.collections.ArraysKt___ArraysKt.toSet, 251)
//
// Native: 17
// (kotlin.collections.toSet__at__kotlin.Array<out|0:0>, 17)
//
//
// startCoroutine
// 0.0072886297
// JVM: 1372
// (kotlin.coroutines.ContinuationKt.startCoroutine, 1372)
//
// Native: 10
// (kotlin.coroutines.startCoroutine__at__kotlin.coroutines.SuspendFunction0<0:0>, 10)
//
//
// setOf
// 0.0065026362
// JVM: 5690
// (kotlin.collections.SetsKt__SetsKt.setOf, 5679)
// (kotlin.collections.SetsKt__SetsJVMKt.setOf, 11)
//
// Native: 37
// (kotlin.collections.setOf, 37)
//
//
// toCollection
// 0.0019311233
// JVM: 3107
// (kotlin.collections.CollectionsKt___CollectionsKt.toCollection, 3029)
// (kotlin.collections.ArraysKt___ArraysKt.toCollection, 78)
//
// Native: 6
// (kotlin.collections.toCollection__at__kotlin.Array<out|0:0>, 6)
//
//
// intercepted
// 0.0016313214
// JVM: 9195
// (kotlin.coroutines.intrinsics.IntrinsicsKt__IntrinsicsJvmKt.intercepted, 9195)
//
// Native: 15
// (kotlin.coroutines.intrinsics.intercepted__at__kotlin.coroutines.Continuation<0:0>, 15)
